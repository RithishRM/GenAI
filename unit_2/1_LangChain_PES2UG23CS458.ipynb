# %% [markdown]
# Name : R.M.Rithish Barath
# SRN : PES2UG23CS458

# %%
# %pip install python-dotenv --upgrade --quiet langchain langchain-google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.5/500.5 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.1/158.1 kB 7.6 MB/s eta 0:00:00

# %% [markdown]
# [AIzaSyBNFO30qs_DKcpfKH4lcWjh4LXcdHc-IIA]
#
# ---

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os

if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API Key:")
# Out:
# Enter your Google API Key:··········

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

#MOdel A : Accountant
llm_focused = ChatGoogleGenerativeAI(model = "gemini-2.5-flash",temperature=0.0)

#Model B : Poet
llm_creative = ChatGoogleGenerativeAI(model="gemini-2.5-flask",temperature=1.0)

# %%
prompt = "Define the word 'Idea' in one sentence."

print("--- FOUCUSED (Temp=0) ---")
print(f"Run 1: {llm_focused.invoke(prompt).content}")
print(f"Run 2: {llm_focused.invoke(prompt).content}")
# Out:
# --- FOUCUSED (Temp=0) ---
# Run 1: An idea is a thought, concept, or suggestion that is formed or exists in the mind.
# Run 2: An idea is a thought, concept, or suggestion that is formed or exists in the mind.

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI

if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API Key:")

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
from langchain_core.messages import SystemMessage, HumanMessage
messages = [
    SystemMessage(content="You are a rude teenager,You use slang"),
    HumanMessage(content="What is the capital of Germany?")
]

response = llm.invoke(messages)
print(response.content)
# Out:
# Ugh, like, seriously? Berlin, duh. Everyone knows that. Are you, like, living under a rock or something?

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API Key:")

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
template = ChatPromptTemplate.from_template("Tell me a fun fact about {topic}.")
parser = StrOutputParser()

# %%
prompt_value = template.invoke({"topic": "Cows"})

response_obj = llm.invoke(prompt_value)

final_text = parser.invoke(response_obj)

print(final_text)
# Out:
# Here's a fun fact about cows:
#
# Cows are very social animals and can form strong bonds, even having "best friends"! They can get stressed if they're separated from their chosen pals.

# %%
chain = template | llm |parser

print(chain.invoke({"topic": "Elephants"}))
# Out:
# Here's a fun one:
#
# Elephants have over **40,000 muscles** in their trunk, but **absolutely no bones**! This incredible flexibility allows them to pick up something as tiny as a single blade of grass or as heavy as a log. It's like a super-powered, multi-purpose limb!
